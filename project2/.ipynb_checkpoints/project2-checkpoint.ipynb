# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pylab
import seaborn as sns
from pandas import Series,DataFrame
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %% [markdown]
# **提出问题：有哪些因素会让船上的人生还率更高？**

# %% [markdown]
# ## 读取数据

# %%
titanic_df = pd.read_csv('titanic-data.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df[]

# %% [markdown]
# ### 探讨生还率和所在舱位等级的关系

# %%
#以 Pclass 来对列表分组，并取出 Survived列
Pclass_sample=titanic_df.groupby(['Pclass'])['Survived']

# %%
#获取不同等级舱位的人数
Pclass_total=Pclass_sample.count()

# %%
Pclass_total
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
#获取不同等级舱位的成功生还人数
Pclass_total_survived=Pclass_sample.sum()

# %%
Pclass_total_survived
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
Pclass_total_not_survived=Pclass_total-Pclass_total_survived

# %%
Pclass_total_not_survived.name='Not Survived'

# %%
Pclass_total_not_survived
# Out:
# Pclass
# 1     80
# 2     97
# 3    372
# Name: Not Survived, dtype: int64

# %%
Pclass_comparison=DataFrame([Pclass_total_survived,Pclass_total_not_survived]).T

# %%
Pclass_comparison
# Out:
#         Survived  Not Survived
# Pclass
# 1            136            80
# 2             87            97
# 3            119           372

# %%
normed_Pclass_comparison=Pclass_comparison.div(Pclass_comparison.sum(1),axis=0)

# %%
normed_Pclass_comparison.plot(kind='barh',stacked=True,figsize=(10,8))

# %%
normed_Pclass_comparison['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ### 数据结论：一等舱的生还率是63%，二等舱是47%，三等舱是24%

# %% [markdown]
# ## 探讨生还率和性别的关系

# %% [markdown]
# ### 准备数据

# %%
#以 Sex 来对列表分组，并取出 Survived列
Sex_sample=titanic_df.groupby(['Sex'])['Survived']

# %%
Sex_sample.groups
# Out:
# {'female': Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#              ...
#              866, 871, 874, 875, 879, 880, 882, 885, 887, 888],
#             dtype='int64', length=314),
#  'male': Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#              ...
#              873, 876, 877, 878, 881, 883, 884, 886, 889, 890],
#             dtype='int64', length=577)}

# %%
Sex_total = Sex_sample.count()

# %%
Sex_total
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
Sex_total_survived = Sex_sample.sum()

# %%
Sex_total_survived
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
Sex_total_not_survived=Sex_total-Sex_total_survived

# %%
Sex_total_not_survived.name='Not Survived'

# %%
Sex_total_not_survived
# Out:
# Sex
# female     81
# male      468
# Name: Not Survived, dtype: int64

# %%
Sex_comparison=DataFrame([Sex_total_survived,Sex_total_not_survived]).T

# %%
Sex_comparison
# Out:
#         Survived  Not Survived
# Sex
# female       233            81
# male         109           468

# %%
normed_Sex_comparison=Sex_comparison.div(Sex_comparison.sum(1),axis=0)

# %%
normed_Sex_comparison.plot(kind='barh',stacked=True,figsize=(10,8))

# %%
normed_Sex_comparison['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# ### 数据结论:女性生还率是74%，男性生还率是19%

# %% [markdown]
# ## 探讨生还率和年龄的关系

# %%
Sex_sample = titanic_df[['Survived','Age']]

# %%
Not_NA_Sex_sample=Sex_sample.dropna()

# %%
Not_NA_Sex_sample.head()
# Out:
#    Survived   Age
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0
# 4         0  35.0

# %%
Not_NA_Sex_sample.describe()
# Out:
#          Survived         Age
# count  714.000000  714.000000
# mean     0.406162   29.699118
# std      0.491460   14.526497
# min      0.000000    0.420000
# 25%      0.000000   20.125000
# 50%      0.000000   28.000000
# 75%      1.000000   38.000000
# max      1.000000   80.000000

# %% [markdown]
# **定义0-14岁为青少年  15-64为中年  65以上为老年 **

# %%
def countDifferentAgeSurvived(aDf):
    s=0  # 青少年人数
    sSurvived=0  #青少年存活人数
    m=0   # 中年人数
    mSurvived=0  #中年存活人数
    l=0  #老年人数
    lSurvived=0  #老年存活人数
    for index,row in aDf.iterrows():
        if row['Age']<=14:
            s+=1
            sSurvived+=row['Survived']
        elif row['Age']<=64:
            m+=1
            mSurvived+=row['Survived']
        else:
            l+=1
            lSurvived+=row['Survived']
    return [(s,sSurvived),(m,mSurvived),(l,lSurvived)]

# %%
AgeSurvived = countDifferentAgeSurvived(Not_NA_Sex_sample)
print AgeSurvived
# Out:
# [(77, 45.0), (626, 244.0), (11, 1.0)]

# %%
for total_number,Survived_number in AgeSurvived:
    print Survived_number/total_number
# Out:
# 0.584415584416
# 0.389776357827
# 0.0909090909091

# %% [markdown]
# ### 数据结论 青少年存活率为58%  中年存活率为39%  老年存活率为9%

# %% [markdown]
# ## 结论：
# 上面我分别探讨了舱位等级，性别，以及年龄与存活率的关系。结果发现，一等舱存活最高。推断是因为一等舱位置好，更适合逃生。女性存活率大于男性。推断是因为绅士风度，男性把更多求生的机会让给了女性。青少年存活率最高，推断也是因为其他人把更多机会让给了青少年。而老年存活率可能和自身身体原因有关。

# %% [markdown]
# ps:上述推导只能说明现象，并不能推导出因果关系。因果关系需要再进一步作出 A/B Test 才能得出结论。
